# %% [markdown]
# # Saving a Plot
# ### savefig()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(10)
y = np.array([3, 6, 1, 5, 9, 10, 3, 4, 2, 8])

plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.savefig("Example-1.png")
plt.show()
