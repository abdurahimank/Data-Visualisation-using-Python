# %% [markdown]
# # Markers
# You can use the keyword argument "**marker**" to emphasize each point with a specified marker:<br>
# For complete data of marker symbols, refer [Matlib Official Guide](https://matplotlib.org/stable/api/markers_api.html?highlight=markers#module-matplotlib.markers).

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o')
plt.show()

# %% [markdown]
# #### Only using markers

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, ls='', marker='o')
plt.show()

# %% [markdown]
# ### Marker Size
# You can use the keyword argument "**markersize**" or the shorter version, "**ms**" to set the size of the markers:

# %%
import matplotlib.pyplot as plot
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', ms=20)
plt.show()

# %% [markdown]
# ### Marker Color
# You can use the keyword argument "**markeredgecolor**" or the shorter "**mec**" to set the color of the edge of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', ms=20, mec='r')
plt.show()

# %% [markdown]
# You can use the keyword argument "**markerfacecolor**" or the shorter "**mfc**" to set the color inside the edge of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', ms=20, mfc='r')
plt.show()

# %% [markdown]
# Use both the "**mec**" and "**mfc**" arguments to color of the entire marker:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', ms=20, mec='r', mfc='r')
plt.show()

# %% [markdown]
# We can also use Hexadecimal color values:<br>
# From "**#000000**" to "**#FFFFFF**" in the **RGB** format.

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', ms=20, mec='#FF0000', mfc='#00FF00')
plt.show()

# %% [markdown]
# Or any of the 140 [supported color names](https://www.w3schools.com/colors/colors_names.asp).

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', ms=20, mec='DarkBlue', mfc='hotpink')
plt.show()

# %% [markdown]
# ### Marker Edge Width
# - **mew**

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([3, 8, 1, 10])

plt.plot(y, marker='o', mew=20)
plt.show()
